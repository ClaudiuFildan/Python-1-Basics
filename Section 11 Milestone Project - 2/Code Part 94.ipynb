# %%
# Step 1
import random

suits=('Hearts','Diamonds','Spades','Clubs')
ranks=('Two','Three','Four','Five','Six','Seven','Eight',
        'Nine','Ten','Jack','Queen','King','Ace')
values={'Two':2,'Three':3,'Four':4,'Five':5,
        'Six':6,'Seven':7,'Eight':8,'Nine':9,
        'Ten':10,'Jack':10,'Queen':10,'King':10,
        'Ace':11}
playing=True

# %%
# Step 2
class Card:
    def __init__(self,suit,rank):
        self.suit=suit
        self.rank=rank
    def __str__(self):
        return self.rank+" of "+self.suit

# %%
# Step 3 
class Deck:
    def __init__(self):
        self.deck=[] # start with an empty list 
        for suit in suits:
            for rank in ranks:
                self.deck.append(Card(suit,rank))
                
    def __str__(self):
        deck_comp= ''
        for card in self.deck:
            deck_comp+='\n'+card.__str__()
        return "The deck has: "+deck_comp 
    
    def shuffle(self):
        random.shuffle(self.deck)
    
    def deal(self):
        single_card=self.deck.pop()
        return single_card

# %%
test_deck=Deck()
test_deck.shuffle()
print(test_deck)
# Out:
# The deck has:
# Three of Clubs
# Eight of Hearts
# Jack of Spades
# Queen of Clubs
# Eight of Spades
# Jack of Diamonds
# Two of Clubs
# Nine of Spades
# Six of Diamonds
# Seven of Diamonds
# Five of Hearts
# Queen of Spades
# King of Clubs
# Seven of Clubs
# King of Hearts
# Jack of Hearts
# Eight of Diamonds
# Three of Hearts
# Nine of Diamonds
# Six of Hearts
# Ten of Diamonds
# Six of Clubs
# Four of Clubs
# Ace of Spades
# King of Spades
# Three of Spades
# Queen of Hearts
# Nine of Hearts
# Queen of Diamonds
# Seven of Spades
# Jack of Clubs
# King of Diamonds
# Two of Spades
# Nine of Clubs
# Seven of Hearts
# Ten of Hearts
# Four of Spades
# Six of Spades
# Ten of Clubs
# Two of Diamonds
# Four of Hearts
# Three of Diamonds
# Eight of Clubs
# Four of Diamonds
# Ten of Spades
# Five of Clubs
# Ace of Hearts
# Five of Spades
# Two of Hearts
# Ace of Diamonds
# Five of Diamonds
# Ace of Clubs

# %%
# Step 4
class Hand:
    def __init__(self):
        self.cards=[] # start with an empty list as we did in the Deck class
        self.value=0  # start with zero value
        self.aces=0   # add an attribute to keep track of aces
        
    def add_card(self,card):
        # card passed in
        # from Deck.deal()-->single Card(suit,rank)
        self.cards.append(card)
        self.value+=values[card.rank]
        
        # track aces
        if card.rank=='Ace':
            self.aces+=1
        
    def adjust_for_ace(self):
        
        # IF TOTAL VALUE >21 AND I STILL HAVE AN ACE
        # THAN CHANGE MY ACE TO BE A 1 INSTEAD OF AN 11
        while self.value > 21 and self.aces>0:
            self.value-=10
            self.aces-=1

# %%
zero=0
one=1
two=2
if zero:
    print('TRUE')

# %%
if two:
    print('TRUE')
# Out:
# TRUE

# %%
test_deck=Deck()
test_deck.shuffle()

# PLAYER 
test_player=Hand()
# Deal 1 card from the deck CARD(suit,rank)
pulled_card=test_deck.deal()
print(pulled_card)
test_player.add_card(pulled_card)
print(test_player.value)
# Out:
# Seven of Spades
# 7

# %%
test_player.add_card(test_deck.deal())
test_player.value
# Out:
# 9

# %%
# Step 5 
class Chips:
    
    def __init__(self,total=100):
        self.total=total # This can be set to defaultvalueor supplied by a user input
        self.bet=0
        
    def win_bet(self):
        self.total+=self.bet
        
    def lose_bet(self):
        self.total-=self.bet

# %%
# Step 6 
def take_bet(chips):
    
    while True:
        
        try:
            chips.bet=int(input('How many chips would you like to bet?'))
        except:
            print('Sorry, a bet must be an integer!')
        else:
            if chips.bet>chips.total:
                print("Sorry, you do not have enough chips! You have: {}".format(chips.total))
            else:
                break

# %%
# Step 7
def hit(deck,hand):
    single_card=deck.deal()
    hand.add_card(single_card)
    hand.adjust_for_ace()

# %%
# Step 8
def hit_or_stand(deck,hand):
    global playing # to control an upcoming while Loop
    
    while True:
        x=input('Hit or Stand? Enter h or s') #HIT ## hh # stand
        
        if x[0].lower()=='h':
            hit(deck,hand)
        elif x[0].lower()=='s':
            print("Player Stands, Dealer's Turn ")
            playing=False
        else:
            print("Sorry, I did no understand that, Please enter h and s only!")
            continue
        break

# %%
# Step 9
def show_some(player,dealer):
    
    # dealer.cards[0]
    
    # Show only ONE of the dealer's cards
    print("\n Dealer's Hand: ")
    print("First card hidden!")
    print(dealer.cards[1])
    
    # Show all (2 cards) of the player's hand/cards
    print("\n Player's hand:")
    for card in player.cards:
        print(card)
    
def show_all(player,dealer):
    
    # Show all the dealer's cards
    
    print("\n Dealer's hand: ")
    for card in dealer.cards:
        print(card)  
    
    print("\n Dealer's hand: ",*dealer.cards,sep='\n')
    # calculate and display value (J+K==20)
    print(f"Value of Dealer's'hand is: {dealer.value} ")
    
    # Show all players cards
    print("\n Player's hand: ")
    for card in player.cards:
        print(card)
    print(f"Value of Player'shand is: {player.value}")

# %%
items=[1,2,3]

# %%
for card in items:
    print(card)
# Out:
# 1
# 2
# 3

# %%
print("Items are:",*items,sep='\n')
# Out:
# Items are:
# 1
# 2
# 3

# %%
# Step 10
def player_busts(player,dealer,chips):
    print('BUST PLAYER!')
    chips.lose_bet()

def player_wins(player,dealer,chips):
    print('PLAYER WINS!')
    chips.win_bet()

def dealer_busts(player, dealer, chips):
    print('PLAYER WINS! DEALER BUSTED!')
    chips.win_bet()
    
def dealer_wins(player, dealer,chips):
    print("DEALER WINS!")
    chips.lose_bet()

def push(player,dealer):
    print('Dealer and player tie! PUSH')

# %%
# Game Logic

# %%
while True:
    # Print an opening statement
    
    print("WELCOME TO BLACKJACK")
    # Create and shuffle the deck, dealtwo cards to each plaayer
    deck=Deck()
    deck.shuffle()
    
    player_hand=Hand()
    player_hand.add_card(deck.deal())
    player_hand.add_card(deck.deal())
    
    dealer_hand=Hand()
    dealer_hand.add_card(deck.deal())
    dealer_hand.add_card(deck.deal())
    
    # Set up the Player's chips
    player_chips=Chips()
    # Prompt the Player for their bet
    take_bet(player_chips)
    
    # Show cards (but keep one dealer card hidden )
    show_some(player_hand,dealer_hand) 
    
    while playing: # recall this  variablefromour hit_or_stand function 
        
        # Prompt for Player to Hit or Stand
        hit_or_stand(deck,player_hand)
        
        # show cards (but keepone dealercard hidden)
        show_some(player_hand,dealer_hand)
        
        # If player's hand exceeds 21, run player_bustd() and break out of loop
        if player_hand.value>21:
            player_busts(player_hand,dealer_hand,player_chips)
            break
            
        # If Player has not busted, play Dealer's hand until Dealer reaches 17
        if player_hand.value <=21:
            
            while dealer_hand.value<player_hand.value:
                hit(deck,dealer_hand)
            
            # Show all cards
            show_all(player_hand,dealer_hand)
            
            # Run different winning scenarios
            if dealer_hand.value>21:
                dealer_busts(player_hand,dealer_hand,player_chips)
            elif dealer_hand.value>player_hand.value:
                dealer_wins(player_hand,dealer_hand,player_chips)
            elif dealer_hand.value<player_hand.value:
                player_wins(player_hand,dealer_hand,player_chips)
            else:
                push(player_hand,dealer_hand)
            
    # Inform Player of their chips total
    print('\n Player total chips are at {}'.format(player_chips.total))
    # Ask to play again
    new_game=input("Would you like to play another hand y/n")
    
    if new_game[0].lower()=='y':
        playing=True
        continue
    else:
        print('Thank you for playing')
        break
# Out:
# WELCOME TO BLACKJACK
# How many chips would you like to bet?2
#
#  Dealer's Hand:
# First card hidden!
# King of Clubs
#
#  Player's hand:
# Five of Diamonds
# Ten of Hearts
# Hit or Stand? Enter h or ss
# Player Stands, Dealer's Turn
#
#  Dealer's Hand:
# First card hidden!
# King of Clubs
#
#  Player's hand:
# Five of Diamonds
# Ten of Hearts
#
#  Dealer's hand:
# Ace of Spades
# King of Clubs
#
#  Dealer's hand:
# Ace of Spades
# King of Clubs
# Value of Dealer's'hand is: 21
#
#  Player's hand:
# Five of Diamonds
# Ten of Hearts
# Value of Player'shand is: 15
# DEALER WINS!
#
#  Player total chips are at 98
# Would you like to play another hand y/ny
# WELCOME TO BLACKJACK
# How many chips would you like to bet?3
#
#  Dealer's Hand:
# First card hidden!
# Three of Hearts
#
#  Player's hand:
# Seven of Diamonds
# King of Hearts
# Hit or Stand? Enter h or ss
# Player Stands, Dealer's Turn
#
#  Dealer's Hand:
# First card hidden!
# Three of Hearts
#
#  Player's hand:
# ...
